# %%
from dezero.variable import Variable
from dezero.function import Square, Exp, square, exp
import numpy as np

# %%
x = Variable(np.array(0.5))

# %%
y = square(exp(square(x)))

# %%
y.backward()

# %%
x.grad
# Out:
# np.float64(3.297442541400256)

# %%
Variable(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Variable(1)
#
# File c:\Users\11562\Desktop\code\dezero\dezero\variable.py:8, in Variable.__init__(self, data)
#       6 if data is not None:
#       7     if not isinstance(data, np.ndarray):
# ----> 8         raise TypeError("{} is not supported".format(type(data)))
#       9 self.data = data
#      10 self.grad = None
#
# TypeError: <class 'int'> is not supported
